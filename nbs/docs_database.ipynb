# %% [markdown]
# # Database Model

# %% [markdown]
# For more information regarding database operations, refer to [Core APIs](core.html#database-operations)

# %% [markdown]
# <!-- AUTO-GENERATED from db/postgres/init.sql by scripts/gen_er_diagram.py. Do not edit by hand. -->
# ![Database ER diagram](db_schema.svg)
